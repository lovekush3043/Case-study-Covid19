# %% [markdown]
# <a href="https://colab.research.google.com/github/lovekush3043/Case-study-Covid19/blob/main/Learning_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ('Hello World')
# Out:
# Hello World

# %%
objective = input("write goal")
print(objective)
# Out:
# write goalARMY
# ARMY

# %%
marks = int(input("enter your marks"))
if marks >= 90:
  print("grade A")
elif marks>=80:
  print("grade B")
elif marks>=70:
  print("grade C")
elif marks>=60:
  print("grade D")
else:
  print("grade E")
# Out:
# enter your marks80
# grade B

# %%
numer = int(input("write any number"))
if numer >0:
 if numer%2 == 0:
    print("number is even")
 else:
   print("number is odd")
else:
  print( "number is negative")

# %%
def number()
    print("a number is mathmetical obeject which helps to count add and substract")

    number()

# %%
# index
My_name = 'Mukesh'

# %%
print(My_name[0]), print(My_name[1]), print(My_name[2]), print(My_name[3]), print(My_name[4]), print(My_name[5])
# Out:
# M
# u
# k
# e
# s
# h
# (None, None, None, None, None, None)

# %%
print(My_name[-1]), print(My_name[-2])
# Out:
# h
# s
# (None, None)

# %%
#string slicing
class_name = "not_class"

# %%
print(class_name[0:6:3])
# Out:
# n_

# %% [markdown]
# # String methods

# %%
Vital = "Abs_noms"

# %%
# Len()
print(len(Vital))
# Out:
# 8

# %%
# Upper
print(Vital.upper())
# Out:
# ABS_NOMS

# %%
#lower
print(Vital.lower())
# Out:
# abs_noms

# %%
#count
print(Vital.count("s"))
# Out:
# 2

# %%
#find
print(Vital.find("n"))
# Out:
# 4

# %%
#split
print(Vital.split(","))
# Out:
# ['Abs_noms']

# %%
#replace
print(Vital.replace("s","t"))
# Out:
# Abt_nomt

# %%
#title
print(Vital.title())
# Out:
# Abs_Noms

# %%
#strip :- for triming space
Who_ = " Mukesh "

# %%
print(Who_.strip())
# Out:
# Mukesh

# %%
#join methods
alpha_words = ("narang", "sarang", "hurdang")

# %%
print(" se ".join(alpha_words))
# Out:
# narang se sarang se hurdang
